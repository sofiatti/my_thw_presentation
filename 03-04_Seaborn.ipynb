# %% [markdown]
# # The Hacker Within: Seaborn

# %% [markdown]
# >My guess, and this is just a guess, is that the big breakthroughs in data analysis will come neither from advances in statistical methods nor from ever-more-complex calculations on ever-larger data sets.
#
# >I think that the biggest gains will come from **tools that will allow us to browse, query, summarize, filter, aggregate, disaggregate, and view their data interactively.**
#
# \- Michael Hochster

# %%
import seaborn as sns

# %% [markdown]
# Do:
# ```ipython
# conda install seaborn # if you have Ananconda
# pip install seaborn # if you have something a different distribution
# ```

# %% [markdown]
# # The Past

# %%
from IPython.display import Image
Image('matplotlib.png', width = 750)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from numpy import arange, sin, pi

t = arange(0.0, 1.0, 0.01)
plt.plot(t, sin(2*2*pi*t))

# %% [markdown]
# # The Future

# %% [markdown]
# # Seaborn is...
# A library for making attractive and informative statistical graphics in Python with only a few lines of code.

# %%
from IPython.display import HTML, Image, display
HTML ('<iframe src=https://web.stanford.edu/~mwaskom/software/seaborn/examples/index.html width=700 height=350></iframe>')
# Out:
# <iframe src=https://web.stanford.edu/~mwaskom/software/seaborn/examples/index.html width=700 height=350></iframe>

# %% [markdown]
# # Seaborn does...

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white")

df = sns.load_dataset("iris")

g = sns.PairGrid(df, diag_sharey=False)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g.map_upper(plt.scatter)
g.map_diag(sns.kdeplot, lw=3)
# Out:
# /Users/carolinesofiatti/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
import seaborn as sns
sns.set(style="darkgrid")

gammas = sns.load_dataset("gammas")
sns.tsplot(gammas, "timepoint", "subject", "ROI", "BOLD signal")

# %%
HTML('<iframe src=http://stanford.edu/~mwaskom/software/seaborn/tutorial.html width=700 height=350></iframe>')
# Out:
# <iframe src=http://stanford.edu/~mwaskom/software/seaborn/tutorial.html width=700 height=350></iframe>

# %% [markdown]
# ### [Light Curves Notebook](https://github.com/sofiatti/SCP/tree/master/lightcurves)

# %% [markdown]
# # Seaborn does more...
#
# It simplifies your life

# %% [markdown]
# >Still plenty of work for tomorrow. Any idea how to get the outside white? I tried editing the colormap by setting the floor to white (and I think I did it successfully, but the plot didn't change)
#
# \- Me, desparately trying to get things to work

# %%
import base64
with open("matplotlibsucks.png", "rb") as image_file:
    im1 = 'data:image/png;base64,' + base64.b64encode(image_file.read())

with open("seabornrules.png", "rb") as image_file:
    im2 = 'data:image/png;base64,' + base64.b64encode(image_file.read())

s = """<table>
<tr>
<th><img src="%s"/></th>
<th><img src="%s"/></th>
</tr></table>"""%(im1, im2)
t=HTML(s)
display(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b174d9d5f9f9> in <module>()
#      11 <th><img src="%s"/></th>
#      12 </tr></table>"""%(im1, im2)
# ---> 13 t=HTML(s)
#      14 display(t)
#
# NameError: name 'HTML' is not defined

# %% [markdown]
# # But there are other things out there

# %% [markdown]
# [Pretty Plot Lib](http://blog.olgabotvinnik.com/prettyplotlib/)
#
#
# [MPLD3](http://mpld3.github.io/)
# [Bokeh](https://pyscience.wordpress.com/2014/09/01/interactive-plotting-in-ipython-notebook-part-12-bokeh/)
# [D3.js](http://d3js.org/)
#
# [Plotly](https://pyscience.wordpress.com/2014/09/02/interactive-plotting-in-ipython-notebook-part-22-plotly-2/)

# %% [markdown]
# ## MPLD3

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# Scatter points
fig, ax = plt.subplots()
np.random.seed(0)
x, y = np.random.normal(size=(2, 200))
color, size = np.random.random((2, 200))

ax.scatter(x, y, c=color, s=500 * size, alpha=0.3)
ax.grid(color='lightgray', alpha=0.7)

# %%
import mpld3
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el215343967961764064051003"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %% [markdown]
# ## Bokeh

# %%
import numpy as np
from bokeh.charts import Line
from bokeh.plotting import output_file, show

# (dict, OrderedDict, lists, arrays and DataFrames are valid inputs)
output_file('line.html')
xyvalues = np.array([[2, 3, 7, 5, 26], [12, 33, 47, 15, 126], [22, 43, 10, 25, 26]])
line = Line(xyvalues, title="line", legend="top_left", ylabel='Languages')
show(line)
# Out:
#
#         <style>
#             /* BEGIN /Users/carolinesofiatti/anaconda/lib/python2.7/site-packages/bokeh/server/static/css/bokeh.min.css */
# ...

# %% [markdown]
# ## D3.js

# %%
from IPython.display import HTML
HTML('<iframe src=http://d3js.org/ width=700 height=350></iframe>')
# Out:
# <iframe src=http://d3js.org/ width=700 height=350></iframe>

# %% [markdown]
# ## Plotly

# %%
from IPython.display import HTML
HTML('<iframe src=https://plot.ly/~PatrickMerlot/178/g2-g3-set-admm-variants-cc-pvtz-cc-pvdz/ width=700 height=350></iframe')
# Out:
# <iframe src=https://plot.ly/~PatrickMerlot/178/g2-g3-set-admm-variants-cc-pvtz-cc-pvdz/ width=700 height=350></iframe
